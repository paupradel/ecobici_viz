# %% [markdown]
# ### Procesamiento de viajes de Ecobici

# %% [markdown]
# __Descripción:__
#
# Se obtiene el AGEB de origen y destino de los viajes de los viajes de ecobici y se obtiene el agregado primedio de los viajes entre AGEBS por hora.
#
# __Input__
#
# - Estaciones de ecobici: Estaciones de ecobici con clave AGEB obtenida de __Uber © 2019 Copyright Uber Technologies, Inc.Data Attributions__
#
# - Viajes Ecobici 2019
# Responsable: Ecobici

# %%
import pandas as pd

# %% [markdown]
# ## Estaciones

# %%
df_estaciones = pd.read_csv('./SIG/data/procesado/CSV/estaciones-de-ecobici_con_AGEB.csv',sep=',')
df_estaciones.head()
# Out:
#     ID                                   Nombre  \
# 0  440        440 REAL DE MAYORAZGO-PUENTE XOCO
# 1  283            283 AV. COYOACÁN-RAFAEL DONDE
# 2  279                279 LA MORENA-PROVIDENCIA
# 3  443             443 BRUNO TRAVEN-GOLONDRINAS
# 4  432  432 CARRILLO PUERTO-AV. MÉXICO-COYOACÁN
#
#                                    Dirección Número  Código po districtCo  \
# 0        440 - Real De Mayorazgo-Puente Xoco    S/N     3330.0          1
# 1            283 - Av. Coyoacán-Rafael Donde    S/N     3103.0          1
# 2                279 - La Morena-Providencia    S/N     3103.0        DVN
# 3  443 - Bruno Trave-Avenida México-Coyoacan    S/N     3340.0          1
# 4             432 - Carrillo Pto-Golondrinas    S/N     3340.0        GPM
#
#                      Colonia  altitude  nearbyStat  location/l  ...  \
# 0         Ampliación Granada       NaN         433   19.360650  ...
# 1         Ampliación Granada       NaN         279   19.398270  ...
# 2            Del Valle Norte       NaN         164   19.399908  ...
# 3         Ampliación Granada       NaN         432   19.359655  ...
# 4  General Pedro Maria Anaya       NaN         442   19.361296  ...
#
#    nearbySt_3 nearbySt_4  nearbySt_5             punto_geo  CVE_AGEB  CVE_MUN  \
# 0         NaN        NaN         NaN   19.36065,-99.168669      0967       14
# 1         NaN        NaN         NaN   19.39827,-99.167383      0045       14
# 2         NaN        NaN         NaN  19.399908,-99.166553      0045       14
# 3         NaN        NaN         NaN  19.359655,-99.162025      0971       14
# 4         NaN        NaN         NaN  19.361296,-99.162581      0971       14
#
#    CVE_LOC CVE_ENT MOVEMENT_I          DISPLAY_NA
# 0        1       9       4550  Movement Zone 4550
# 1        1       9       4551  Movement Zone 4551
# 2        1       9       4551  Movement Zone 4551
# 3        1       9       4553  Movement Zone 4553
# 4        1       9       4553  Movement Zone 4553
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Viajes ecobici

# %%
df_viajes = pd.read_csv('./data/2019/ecobici_2019.csv',sep=',')
df_viajes.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,1,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1   9196                   136                     55            36
# 2   2612                   115                     29            38
# 3   7463                   115                     29            43
# 4   3987                    35                    136            37
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro Unnamed: 9
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44        NaN
# 1   01/01/2019   01/01/2019              M     0:42:11     0:12:05        NaN
# 2   01/01/2019   01/01/2019              M     0:37:47     0:13:15        NaN
# 3   01/01/2019   01/01/2019              M     0:38:04     0:13:36        NaN
# 4   01/01/2019   01/01/2019              M     0:22:47     0:15:30        NaN

# %% [markdown]
# ### merge viajes e info de estaciones
#
# Se obtiene ageb por estación de origen y destino.

# %% [markdown]
# #### Clave AGEB arribo

# %%
df_viajes_ageb = df_viajes.merge(df_estaciones[['ID','CVE_AGEB']], left_on='Ciclo_Estacion_Arribo', right_on='ID')

# %%
df_viajes_ageb.rename(columns={'CVE_AGEB': 'CVE_AGEB_arribo'}, inplace=True)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  10531                    36                    347            36
# 2   4011                    36                    232            43
# 3  11768                    36                    153            70
# 4   9460                    36                    151            29
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro Unnamed: 9  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44        NaN
# 1   01/01/2019   01/01/2019              M     5:49:51     5:28:52        NaN
# 2   01/01/2019   01/01/2019              M     8:36:54     8:28:24        NaN
# 3   01/01/2019   01/01/2019              M     9:53:42     9:42:40        NaN
# 4   01/01/2019   01/01/2019              M    10:00:48     9:45:18        NaN
#
#    ID CVE_AGEB_arribo
# 0  36            1089
# 1  36            1089
# 2  36            1089
# 3  36            1089
# 4  36            1089

# %% [markdown]
# #### Clave AGEB destino

# %%
df_viajes_ageb = df_viajes_ageb.merge(df_estaciones[['ID','CVE_AGEB']], left_on='Ciclo_Estacion_Retiro', right_on='ID')

# %%
df_viajes_ageb.rename(columns={'CVE_AGEB': 'CVE_AGEB_retiro'}, inplace=True)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro Unnamed: 9  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44        NaN
# 1   01/01/2019   01/01/2019              M    23:02:34    22:57:15        NaN
# 2   02/01/2019   02/01/2019              M     7:42:30     7:38:25        NaN
# 3   03/01/2019   03/01/2019              M     7:41:55     7:37:37        NaN
# 4   03/01/2019   03/01/2019              M     8:37:24     8:32:25        NaN
#
#    ID_x CVE_AGEB_arribo  ID_y CVE_AGEB_retiro
# 0    36            1089    67            1318
# 1    36            1089    67            1318
# 2    36            1089    67            1318
# 3    36            1089    67            1318
# 4    36            1089    67            1318

# %% [markdown]
# ### Eliminamos columnas no usadas

# %%
df_viajes_ageb.columns
# Out:
# Index(['Bici', 'Ciclo_Estacion_Arribo', 'Ciclo_Estacion_Retiro',
#        'Edad_Usuario', 'Fecha_Arribo', 'Fecha_Retiro', 'Genero_Usuario',
#        'Hora_Arribo', 'Hora_Retiro', 'Unnamed: 9', 'ID_x', 'CVE_AGEB_arribo',
#        'ID_y', 'CVE_AGEB_retiro'],
#       dtype='object')

# %%
df_viajes_ageb.drop(['Unnamed: 9','ID_x','ID_y'], axis=1, inplace=True)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44
# 1   01/01/2019   01/01/2019              M    23:02:34    22:57:15
# 2   02/01/2019   02/01/2019              M     7:42:30     7:38:25
# 3   03/01/2019   03/01/2019              M     7:41:55     7:37:37
# 4   03/01/2019   03/01/2019              M     8:37:24     8:32:25
#
#   CVE_AGEB_arribo CVE_AGEB_retiro
# 0            1089            1318
# 1            1089            1318
# 2            1089            1318
# 3            1089            1318
# 4            1089            1318

# %% [markdown]
# ## Obtenemos la columna de hora de retiro:

# %%
df_viajes_ageb['Hora_Retiro_round'] = df_viajes_ageb['Hora_Retiro'].str.split(':').str[0].astype(int)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44
# 1   01/01/2019   01/01/2019              M    23:02:34    22:57:15
# 2   02/01/2019   02/01/2019              M     7:42:30     7:38:25
# 3   03/01/2019   03/01/2019              M     7:41:55     7:37:37
# 4   03/01/2019   03/01/2019              M     8:37:24     8:32:25
#
#   CVE_AGEB_arribo CVE_AGEB_retiro  Hora_Retiro_round
# 0            1089            1318                  0
# 1            1089            1318                 22
# 2            1089            1318                  7
# 3            1089            1318                  7
# 4            1089            1318                  8

# %%
df_viajes_ageb.dtypes
# Out:
# Bici                     object
# Ciclo_Estacion_Arribo    object
# Ciclo_Estacion_Retiro     int64
# Edad_Usuario              int64
# Fecha_Arribo             object
# Fecha_Retiro             object
# Genero_Usuario           object
# Hora_Arribo              object
# Hora_Retiro              object
# CVE_AGEB_arribo          object
# CVE_AGEB_retiro          object
# Hora_Retiro_round         int64
# dtype: object

# %% [markdown]
# ## Obtenemos el tiempo de cada viaje:

# %% [markdown]
# Eliminamos filas con errores de formato:

# %%
df_viajes_ageb[df_viajes_ageb['Hora_Retiro']=='18::']
# Out:
#          Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 3127563  8026                   400                     18            19
#
#         Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro  \
# 3127563   28/04/2019   26/04/2019              M    01:15:10        18::
#
#         CVE_AGEB_arribo CVE_AGEB_retiro  Hora_Retiro_round
# 3127563            0755            0837                 18

# %%
df_viajes_ageb.drop([3127563],inplace=True)

# %% [markdown]
# Convetimos a datetime:

# %%
df_viajes_ageb['Hora_Retiro'] = pd.to_datetime(df_viajes_ageb['Hora_Retiro'], format='%H:%M:%S')

df_viajes_ageb['Hora_Arribo'] = pd.to_datetime(df_viajes_ageb['Hora_Arribo'], format='%H:%M:%S')

# %% [markdown]
# Verificamos que las horas de arribo y reutro sean datetime

# %%
df_viajes_ageb.dtypes
# Out:
# Bici                             object
# Ciclo_Estacion_Arribo            object
# Ciclo_Estacion_Retiro             int64
# Edad_Usuario                      int64
# Fecha_Arribo                     object
# Fecha_Retiro                     object
# Genero_Usuario                   object
# Hora_Arribo              datetime64[ns]
# Hora_Retiro              datetime64[ns]
# CVE_AGEB_arribo                  object
# CVE_AGEB_retiro                  object
# Hora_Retiro_round                 int64
# dtype: object

# %% [markdown]
# restamos las columnas para obtener el tiempo

# %%
df_viajes_ageb['duracion_viaje'] = df_viajes_ageb['Hora_Arribo'] - df_viajes_ageb['Hora_Retiro']

# %%
df_viajes_ageb['duracion_viaje_minutos'] = df_viajes_ageb['duracion_viaje'].astype('str').str.split(':').str[1].astype(int)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario         Hora_Arribo  \
# 0   01/01/2019   01/01/2019              M 1900-01-01 00:14:03
# 1   01/01/2019   01/01/2019              M 1900-01-01 23:02:34
# 2   02/01/2019   02/01/2019              M 1900-01-01 07:42:30
# 3   03/01/2019   03/01/2019              M 1900-01-01 07:41:55
# 4   03/01/2019   03/01/2019              M 1900-01-01 08:37:24
#
#           Hora_Retiro CVE_AGEB_arribo CVE_AGEB_retiro  Hora_Retiro_round  \
# 0 1900-01-01 00:08:44            1089            1318                  0
# 1 1900-01-01 22:57:15            1089            1318                 22
# 2 1900-01-01 07:38:25            1089            1318                  7
# 3 1900-01-01 07:37:37            1089            1318                  7
# 4 1900-01-01 08:32:25            1089            1318                  8
#
#   duracion_viaje  duracion_viaje_minutos
# 0       00:05:19                       5
# 1       00:05:19                       5
# 2       00:04:05                       4
# 3       00:04:18                       4
# 4       00:04:59                       4

# %%
df_viajes_ageb.drop(['Bici','Ciclo_Estacion_Arribo','Ciclo_Estacion_Retiro','Fecha_Arribo',
                    'Fecha_Retiro','duracion_viaje','Hora_Arribo','Hora_Retiro'], axis=1, inplace=True)

# %%
print(df_viajes_ageb['CVE_AGEB_retiro'].nunique(),df_viajes_ageb['CVE_AGEB_arribo'].nunique())
# Out:
# 142 142

# %% [raw]
# df_viajes_ageb.to_csv('./data/procesado/datos_ecobici_ageb.csv',index=False)

# %%
df_viajes_ageb.head()
# Out:
#    Edad_Usuario Genero_Usuario CVE_AGEB_arribo CVE_AGEB_retiro  \
# 0            36              M            1089            1318
# 1            36              M            1089            1318
# 2            34              M            1089            1318
# 3            34              M            1089            1318
# 4            24              M            1089            1318
#
#    Hora_Retiro_round  duracion_viaje_minutos
# 0                  0                       5
# 1                 22                       5
# 2                  7                       4
# 3                  7                       4
# 4                  8                       4

# %% [markdown]
# ### Obtención de genero de usuarios por viaje:

# %% [raw]
# df_viajes_ageb  = pd.read_csv('./data/procesado/datos_ecobici_ageb.csv')

# %%
print(df_viajes_ageb['CVE_AGEB_retiro'].nunique(),df_viajes_ageb['CVE_AGEB_arribo'].nunique())
# Out:
# 142 142

# %%
df_viajes_ageb.head()
# Out:
#    Edad_Usuario Genero_Usuario CVE_AGEB_arribo CVE_AGEB_retiro  \
# 0            36              M            1089            1318
# 1            36              M            1089            1318
# 2            34              M            1089            1318
# 3            34              M            1089            1318
# 4            24              M            1089            1318
#
#    Hora_Retiro_round  duracion_viaje_minutos
# 0                  0                       5
# 1                 22                       5
# 2                  7                       4
# 3                  7                       4
# 4                  8                       4

# %%
df_viajes_ageb['Genero_Usuario_F'] = pd.get_dummies(df_viajes_ageb['Genero_Usuario'])["F"]
df_viajes_ageb['Genero_Usuario_M'] = pd.get_dummies(df_viajes_ageb['Genero_Usuario'])["M"]

# %%
df_viajes_ageb.head()
# Out:
#    Edad_Usuario Genero_Usuario CVE_AGEB_arribo CVE_AGEB_retiro  \
# 0            36              M            1089            1318
# 1            36              M            1089            1318
# 2            34              M            1089            1318
# 3            34              M            1089            1318
# 4            24              M            1089            1318
#
#    Hora_Retiro_round  duracion_viaje_minutos  Genero_Usuario_F  \
# 0                  0                       5                 0
# 1                 22                       5                 0
# 2                  7                       4                 0
# 3                  7                       4                 0
# 4                  8                       4                 0
#
#    Genero_Usuario_M
# 0                 1
# 1                 1
# 2                 1
# 3                 1
# 4                 1

# %%
df_viajes_ageb.dtypes
# Out:
# Edad_Usuario               int64
# Genero_Usuario            object
# CVE_AGEB_arribo           object
# CVE_AGEB_retiro           object
# Hora_Retiro_round          int64
# duracion_viaje_minutos     int64
# Genero_Usuario_F           uint8
# Genero_Usuario_M           uint8
# dtype: object

# %%
print(df_viajes_ageb['CVE_AGEB_retiro'].nunique(),df_viajes_ageb['CVE_AGEB_arribo'].nunique())
# Out:
# 142 142

# %%
df_viajes_ageb_agg = df_viajes_ageb.groupby(['CVE_AGEB_arribo','CVE_AGEB_retiro','Hora_Retiro_round' ]).agg({'Edad_Usuario':['count', 'mean'], 
                         'duracion_viaje_minutos':['mean','min','max'],
                                                                                       'Genero_Usuario_F':['sum'],
                                                                                       'Genero_Usuario_M':['sum'],
                                                                                      
                                                                                      }).reset_index(drop=False)
df_viajes_ageb_agg.columns = ['_'.join(col) for col in df_viajes_ageb_agg.columns]

# %%
df_viajes_ageb_agg.head()
# Out:
#   CVE_AGEB_arribo_ CVE_AGEB_retiro_  Hora_Retiro_round_  Edad_Usuario_count  \
# 0             0011             0011                   0                   7
# 1             0011             0011                   5                   7
# 2             0011             0011                   6                  13
# 3             0011             0011                   7                  35
# 4             0011             0011                   8                  72
#
#    Edad_Usuario_mean  duracion_viaje_minutos_mean  duracion_viaje_minutos_min  \
# 0          25.000000                    21.142857                           2
# 1          41.571429                     1.571429                           1
# 2          32.230769                     2.153846                           1
# 3          35.571429                     4.000000                           1
# 4          37.416667                     4.555556                           1
#
#    duracion_viaje_minutos_max  Genero_Usuario_F_sum  Genero_Usuario_M_sum
# 0                          35                   2.0                   5.0
# 1                           2                   0.0                   7.0
# 2                           7                   4.0                   9.0
# 3                          51                   7.0                  28.0
# 4                          59                  20.0                  52.0

# %%
print(df_viajes_ageb_agg['CVE_AGEB_arribo_'].nunique(),df_viajes_ageb_agg['CVE_AGEB_retiro_'].nunique())
# Out:
# 142 142

# %%
df_viajes_ageb_agg.head(5)
# Out:
#   CVE_AGEB_arribo_ CVE_AGEB_retiro_  Hora_Retiro_round_  Edad_Usuario_count  \
# 0             0011             0011                   0                   7
# 1             0011             0011                   5                   7
# 2             0011             0011                   6                  13
# 3             0011             0011                   7                  35
# 4             0011             0011                   8                  72
#
#    Edad_Usuario_mean  duracion_viaje_minutos_mean  duracion_viaje_minutos_min  \
# 0          25.000000                    21.142857                           2
# 1          41.571429                     1.571429                           1
# 2          32.230769                     2.153846                           1
# 3          35.571429                     4.000000                           1
# 4          37.416667                     4.555556                           1
#
#    duracion_viaje_minutos_max  Genero_Usuario_F_sum  Genero_Usuario_M_sum
# 0                          35                   2.0                   5.0
# 1                           2                   0.0                   7.0
# 2                           7                   4.0                   9.0
# 3                          51                   7.0                  28.0
# 4                          59                  20.0                  52.0

# %% [markdown]
# Definimos una función para obtener el número de mujeres y de hombres:

# %%
def procentaje_homvres(row):
    return round(row['Genero_Usuario_M_sum']*10 / (row['Genero_Usuario_F_sum'] + row['Genero_Usuario_M_sum']),0)

# %%
df_viajes_ageb_agg['porcentage_hombres'] = df_viajes_ageb_agg.apply(procentaje_homvres, axis=1)

# %%
df_viajes_ageb_agg['porcentage_mujeres'] = 10 - df_viajes_ageb_agg['porcentage_hombres']

# %%
df_viajes_ageb_agg.head()
# Out:
#   CVE_AGEB_arribo_ CVE_AGEB_retiro_  Hora_Retiro_round_  Edad_Usuario_count  \
# 0             0011             0011                   0                   7
# 1             0011             0011                   5                   7
# 2             0011             0011                   6                  13
# 3             0011             0011                   7                  35
# 4             0011             0011                   8                  72
#
#    Edad_Usuario_mean  duracion_viaje_minutos_mean  duracion_viaje_minutos_min  \
# 0          25.000000                    21.142857                           2
# 1          41.571429                     1.571429                           1
# 2          32.230769                     2.153846                           1
# 3          35.571429                     4.000000                           1
# 4          37.416667                     4.555556                           1
#
#    duracion_viaje_minutos_max  Genero_Usuario_F_sum  Genero_Usuario_M_sum  \
# 0                          35                   2.0                   5.0
# 1                           2                   0.0                   7.0
# 2                           7                   4.0                   9.0
# 3                          51                   7.0                  28.0
# 4                          59                  20.0                  52.0
#
#    porcentage_hombres  porcentage_mujeres
# 0                 7.0                 3.0
# 1                10.0                 0.0
# 2                 7.0                 3.0
# 3                 8.0                 2.0
# 4                 7.0                 3.0

# %%
df_viajes_ageb_agg.to_csv('./data/production_data/viajes_ecobici.csv',index=False)
