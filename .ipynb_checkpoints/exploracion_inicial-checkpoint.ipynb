# %%
import pandas as pd
import pickle

import pandas as pd
import dask.dataframe as dd
import time

import scipy.stats

# %% [markdown]
# ## Obtencion de AGEBS de interés:

# %%
df_estaciones = pd.read_csv("./SIG/data/procesado/CSV/estaciones-de-ecobici_con_AGEB.csv")
df_estaciones.head()
# Out:
#     ID                                   Nombre  \
# 0  440        440 REAL DE MAYORAZGO-PUENTE XOCO
# 1  283            283 AV. COYOACÁN-RAFAEL DONDE
# 2  279                279 LA MORENA-PROVIDENCIA
# 3  443             443 BRUNO TRAVEN-GOLONDRINAS
# 4  432  432 CARRILLO PUERTO-AV. MÉXICO-COYOACÁN
#
#                                    Dirección Número  Código po districtCo  \
# 0        440 - Real De Mayorazgo-Puente Xoco    S/N     3330.0          1
# 1            283 - Av. Coyoacán-Rafael Donde    S/N     3103.0          1
# 2                279 - La Morena-Providencia    S/N     3103.0        DVN
# 3  443 - Bruno Trave-Avenida México-Coyoacan    S/N     3340.0          1
# 4             432 - Carrillo Pto-Golondrinas    S/N     3340.0        GPM
#
#                      Colonia  altitude  nearbyStat  location/l  ...  \
# 0         Ampliación Granada       NaN         433   19.360650  ...
# 1         Ampliación Granada       NaN         279   19.398270  ...
# 2            Del Valle Norte       NaN         164   19.399908  ...
# 3         Ampliación Granada       NaN         432   19.359655  ...
# 4  General Pedro Maria Anaya       NaN         442   19.361296  ...
#
#    nearbySt_3 nearbySt_4  nearbySt_5             punto_geo  CVE_AGEB  CVE_MUN  \
# 0         NaN        NaN         NaN   19.36065,-99.168669      0967       14
# 1         NaN        NaN         NaN   19.39827,-99.167383      0045       14
# 2         NaN        NaN         NaN  19.399908,-99.166553      0045       14
# 3         NaN        NaN         NaN  19.359655,-99.162025      0971       14
# 4         NaN        NaN         NaN  19.361296,-99.162581      0971       14
#
#    CVE_LOC CVE_ENT MOVEMENT_I          DISPLAY_NA
# 0        1       9       4550  Movement Zone 4550
# 1        1       9       4551  Movement Zone 4551
# 2        1       9       4551  Movement Zone 4551
# 3        1       9       4553  Movement Zone 4553
# 4        1       9       4553  Movement Zone 4553
#
# [5 rows x 24 columns]

# %%
lista_agebs = df_estaciones['CVE_AGEB'].unique().tolist()
len(lista_agebs)
# Out:
# 143

# %% [markdown]
# Guardamos lo AGEBS en una lista:

# %%
with open("./data/lista_agebs.txt", "wb") as fp:
    pickle.dump(lista_agebs, fp)

# %% [markdown]
# ## Leamos el archivo de viajes de UBER

# %%
path_uber_trips = "./data/uber/mexico_city-agebs-2019-2-All-HourlyAggregate.csv"

# %%
t=time.clock()
df_trips = dd.read_csv(path_uber_trips)
df_trips = df_trips.compute()
print("load train: " , time.clock()-t)
# Out:
# load train:  70.403141

# %%
df_trips.head()
# Out:
#    sourceid  dstid  hod  mean_travel_time  standard_deviation_travel_time  \
# 0      3409   2789   11           1593.14                          546.69
# 1      3241   4552    7           2198.52                          501.11
# 2      3185   2672    8           2115.36                          457.21
# 3       201   2147   11            641.64                          319.21
# 4       301   1147   11           1632.54                          550.32
#
#    geometric_mean_travel_time  geometric_standard_deviation_travel_time
# 0                     1529.45                                      1.30
# 1                     2119.54                                      1.34
# 2                     2065.90                                      1.24
# 3                      591.79                                      1.44
# 4                     1566.17                                      1.31

# %%
df_trips = df_trips[df_trips["sourceid"].astype(str).isin(lista_agebs)]

# %%
df_trips.to_csv('./data/procesado/mexico_city-agebs-2019-2-All-HourlyAggregate_filter.csv')

# %%
df_trips.dtypes
# Out:
# sourceid                                      int64
# dstid                                         int64
# hod                                           int64
# mean_travel_time                            float64
# standard_deviation_travel_time              float64
# geometric_mean_travel_time                  float64
# geometric_standard_deviation_travel_time    float64
# dtype: object

# %%
df_trips.reset_index(drop=True, inplace=True)

# %%
df_trips.head()
# Out:
#    sourceid  dstid  hod  mean_travel_time  standard_deviation_travel_time  \
# 0      1375   2067   11           2125.00                          640.25
# 1      1534   2452    5            766.98                          243.10
# 2      1106   1944   19           1298.45                          258.22
# 3      1303   1894   16           1124.22                          278.44
# 4      1375   1174   16           1222.41                          403.44
#
#    geometric_mean_travel_time  geometric_standard_deviation_travel_time
# 0                     2039.71                                      1.32
# 1                      743.55                                      1.28
# 2                     1274.28                                      1.21
# 3                     1098.68                                      1.22
# 4                     1173.74                                      1.31

# %% [markdown]
# ### tiempo máximo y mínimos por viaje y hora.
# Suponemos una distribución normal con media 'mean_travel_time' y desviación estandar 'standard_deviation_travel_time>'

# %%
def travel_min(mean,std):
    min = scipy.stats.norm(mean, std).ppf(.10)
    #max = scipy.stats.norm(mean, std).ppf(.90)
    return(min)
def travel_max(mean,std):
    #min = scipy.stats.norm(mean, std).ppf(.10)
    max = scipy.stats.norm(mean, std).ppf(.90)
    return(max)

# %%
df_trips['min_travel_time'] = 0
df_trips['max_travel_time'] = 0

# %%
df_trips['min_travel_time'] =  df_trips.apply(
    lambda row : travel_min(row['mean_travel_time'], 
                            row['standard_deviation_travel_time']), axis = 1)

# %%
df_trips['max_travel_time'] =  df_trips.apply(
    lambda row : travel_max(row['mean_travel_time'], 
                            row['standard_deviation_travel_time']), axis = 1)

# %%
df_trips.to_csv('./data/procesado/mexico_city-agebs-2019-2-All-HourlyAggregate_filter.csv')

# %%
df_trips.head()
# Out:
#    sourceid  dstid  hod  mean_travel_time  standard_deviation_travel_time  \
# 0      1375   2067   11           2125.00                          640.25
# 1      1534   2452    5            766.98                          243.10
# 2      1106   1944   19           1298.45                          258.22
# 3      1303   1894   16           1124.22                          278.44
# 4      1375   1174   16           1222.41                          403.44
#
#    geometric_mean_travel_time  geometric_standard_deviation_travel_time  \
# 0                     2039.71                                      1.32
# 1                      743.55                                      1.28
# 2                     1274.28                                      1.21
# 3                     1098.68                                      1.22
# 4                     1173.74                                      1.31
#
#    min_travel_time  max_travel_time
# 0      1304.486610      2945.513390
# 1       455.434814      1078.525186
# 2       967.527755      1629.372245
# 3       767.384782      1481.055218
# 4       705.380836      1739.439164

# %%
df_trips.dtypes
# Out:
# sourceid                                      int64
# dstid                                         int64
# hod                                           int64
# mean_travel_time                            float64
# standard_deviation_travel_time              float64
# geometric_mean_travel_time                  float64
# geometric_standard_deviation_travel_time    float64
# min_travel_time                             float64
# max_travel_time                             float64
# dtype: object

# %% [markdown]
# ## Estaciones

# %%
df_estaciones = pd.read_csv('./SIG/data/procesado/CSV/estaciones-de-ecobici_con_AGEB.csv',sep=',')
df_estaciones.head()
# Out:
#     ID                                   Nombre  \
# 0  440        440 REAL DE MAYORAZGO-PUENTE XOCO
# 1  283            283 AV. COYOACÁN-RAFAEL DONDE
# 2  279                279 LA MORENA-PROVIDENCIA
# 3  443             443 BRUNO TRAVEN-GOLONDRINAS
# 4  432  432 CARRILLO PUERTO-AV. MÉXICO-COYOACÁN
#
#                                    Dirección Número  Código po districtCo  \
# 0        440 - Real De Mayorazgo-Puente Xoco    S/N     3330.0          1
# 1            283 - Av. Coyoacán-Rafael Donde    S/N     3103.0          1
# 2                279 - La Morena-Providencia    S/N     3103.0        DVN
# 3  443 - Bruno Trave-Avenida México-Coyoacan    S/N     3340.0          1
# 4             432 - Carrillo Pto-Golondrinas    S/N     3340.0        GPM
#
#                      Colonia  altitude  nearbyStat  location/l  ...  \
# 0         Ampliación Granada       NaN         433   19.360650  ...
# 1         Ampliación Granada       NaN         279   19.398270  ...
# 2            Del Valle Norte       NaN         164   19.399908  ...
# 3         Ampliación Granada       NaN         432   19.359655  ...
# 4  General Pedro Maria Anaya       NaN         442   19.361296  ...
#
#    nearbySt_3 nearbySt_4  nearbySt_5             punto_geo  CVE_AGEB  CVE_MUN  \
# 0         NaN        NaN         NaN   19.36065,-99.168669      0967       14
# 1         NaN        NaN         NaN   19.39827,-99.167383      0045       14
# 2         NaN        NaN         NaN  19.399908,-99.166553      0045       14
# 3         NaN        NaN         NaN  19.359655,-99.162025      0971       14
# 4         NaN        NaN         NaN  19.361296,-99.162581      0971       14
#
#    CVE_LOC CVE_ENT MOVEMENT_I          DISPLAY_NA
# 0        1       9       4550  Movement Zone 4550
# 1        1       9       4551  Movement Zone 4551
# 2        1       9       4551  Movement Zone 4551
# 3        1       9       4553  Movement Zone 4553
# 4        1       9       4553  Movement Zone 4553
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Viajes ecobici

# %%
df_viajes = pd.read_csv('./data/2019/ecobici_2019.csv',sep=',')
df_viajes.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1   9196                   136                     55            36
# 2   2612                   115                     29            38
# 3   7463                   115                     29            43
# 4   3987                    35                    136            37
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro Unnamed: 9
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44        NaN
# 1   01/01/2019   01/01/2019              M     0:42:11     0:12:05        NaN
# 2   01/01/2019   01/01/2019              M     0:37:47     0:13:15        NaN
# 3   01/01/2019   01/01/2019              M     0:38:04     0:13:36        NaN
# 4   01/01/2019   01/01/2019              M     0:22:47     0:15:30        NaN

# %%
df_viajes["ID"] = df_viajes["Ciclo_Estacion_Arribo"]

# %% [markdown]
# #### concat viajes e info de estaciones

# %%
df_viajes_ageb = df_viajes.merge(df_estaciones, left_on='Ciclo_Estacion_Arribo', right_on='ID')

# %%
df_viajes_ageb.columns
# Out:
# Index(['Bici', 'Ciclo_Estacion_Arribo', 'Ciclo_Estacion_Retiro',
#        'Edad_Usuario', 'Fecha_Arribo', 'Fecha_Retiro', 'Genero_Usuario',
#        'Hora_Arribo', 'Hora_Retiro', 'Unnamed: 9', 'ID_x', 'ID_y', 'Nombre',
#        'Dirección', 'Número', 'Código po', 'districtCo', 'Colonia', 'altitude',
#        'nearbyStat', 'location/l', 'location_1', 'Tipo de es', 'nearbySt_1',
#        'nearbySt_2', 'nearbySt_3', 'nearbySt_4', 'nearbySt_5', 'punto_geo',
#        'CVE_AGEB', 'CVE_MUN', 'CVE_LOC', 'CVE_ENT', 'MOVEMENT_I',
#        'DISPLAY_NA'],
#       dtype='object')

# %%
df_viajes_ageb.groupby(['CVE_AGEB','Hora_Retiro']).mean()
# Out:
#                       Ciclo_Estacion_Retiro  Edad_Usuario   ID_y  Código po  \
# CVE_AGEB Hora_Retiro
# 0011     00:01:35                     136.0          41.0  276.0     3020.0
#          00:02:31                     148.0          25.0  276.0     3020.0
#          00:02:41                     295.0          26.0  277.0     3020.0
#          00:03:29                     295.0          44.0  277.0     3020.0
#          00:03:35                     295.0          44.0  277.0     3020.0
# ...                                     ...           ...    ...        ...
# 1534     9:59:49                       11.0          48.0  124.0     6500.0
#          9:59:51                      124.0          30.0  124.0     6500.0
#          9:59:54                      107.0          26.0  124.0     6500.0
#          9:59:55                      141.0          27.0  124.0     6500.0
#          9:59:57                      126.0          43.0  124.0     6500.0
#
#                       altitude  nearbyStat  location/l  location_1  \
# CVE_AGEB Hora_Retiro
# 0011     00:01:35          NaN       277.0   19.401986  -99.156366
#          00:02:31          NaN       277.0   19.401986  -99.156366
#          00:02:41          NaN       165.0   19.401807  -99.159090
#          00:03:29          NaN       165.0   19.401807  -99.159090
#          00:03:35          NaN       165.0   19.401807  -99.159090
# ...                        ...         ...         ...         ...
# 1534     9:59:49           NaN       119.0   19.422392  -99.150358
#          9:59:51           NaN       119.0   19.422392  -99.150358
#          9:59:54           NaN       119.0   19.422392  -99.150358
#          9:59:55           NaN       119.0   19.422392  -99.150358
#          9:59:57           NaN       119.0   19.422392  -99.150358
#
#                       nearbySt_1  nearbySt_2  nearbySt_3  nearbySt_4  \
# CVE_AGEB Hora_Retiro
# 0011     00:01:35          280.0       281.0         NaN         NaN
#          00:02:31          280.0       281.0         NaN         NaN
#          00:02:41          276.0       280.0         NaN         NaN
#          00:03:29          276.0       280.0         NaN         NaN
#          00:03:35          276.0       280.0         NaN         NaN
# ...                          ...         ...         ...         ...
# 1534     9:59:49           123.0       133.0         NaN         NaN
#          9:59:51           123.0       133.0         NaN         NaN
#          9:59:54           123.0       133.0         NaN         NaN
#          9:59:55           123.0       133.0         NaN         NaN
#          9:59:57           123.0       133.0         NaN         NaN
#
#                       nearbySt_5  CVE_MUN  CVE_LOC  CVE_ENT  MOVEMENT_I
# CVE_AGEB Hora_Retiro
# 0011     00:01:35            NaN     14.0      1.0      9.0      4580.0
#          00:02:31            NaN     14.0      1.0      9.0      4580.0
#          00:02:41            NaN     14.0      1.0      9.0      4580.0
#          00:03:29            NaN     14.0      1.0      9.0      4580.0
#          00:03:35            NaN     14.0      1.0      9.0      4580.0
# ...                          ...      ...      ...      ...         ...
# 1534     9:59:49             NaN     15.0      1.0      9.0      4779.0
#          9:59:51             NaN     15.0      1.0      9.0      4779.0
#          9:59:54             NaN     15.0      1.0      9.0      4779.0
#          9:59:55             NaN     15.0      1.0      9.0      4779.0
#          9:59:57             NaN     15.0      1.0      9.0      4779.0
#
# [3892173 rows x 17 columns]
