# %% [markdown]
# # Procesamiento de viajes de Ecobici

# %% [markdown]
# __Descripción:__
#
# Se obtiene el AGEB de origen y destino de los viajes de los viajes de ecobici y se obtiene el agregado primedio de los viajes entre AGEBS por hora.
#
# __Input__
#
# - Estaciones de ecobici: Estaciones de ecobici con clave AGEB obtenida de __Uber © 2019 Copyright Uber Technologies, Inc.Data Attributions__
#
# - Viajes Ecobici 2019
# Responsable: Ecobici

# %%
import pandas as pd

# %% [markdown]
# ## Estaciones

# %%
df_estaciones = pd.read_csv('./data/SIG/procesado/CSV/estaciones-de-ecobici_con_AGEB.csv',sep=',')
df_estaciones['CVE_AGEB'] = [''.join(filter(lambda x: x.isdigit(), row)) for row in df_estaciones['CVE_AGEB']]
df_estaciones['CVE_AGEB'] = df_estaciones['CVE_AGEB'].astype(int)

df_estaciones.sort_values("ID").head(5)
# Out:
#      ID                         Nombre                            Dirección  \
# 295   1          1 RIO SENA-RIO BALSAS            001 - Río Sena-Río Balsas
# 173   2  2 RIO GUADALQUIVIR-RIO BALSAS  002 - Río Guadalquivir - Río Balsas
# 288   3          3 REFORMA-INSURGENTES          003 - Reforma - Insurgentes
# 172   4          4 RIO NILO-RIO PANUCO          004 - Río Nilo - Río Panuco
# 364   5         5 RIO PANUCO-RIO TIBER           005 - Río Pánuco Río Tiber
#
#     Número  Código po districtCo             Colonia  altitude  nearbyStat  \
# 295    S/N     6500.0        CUA          Cuauhtémoc       NaN           3
# 173    S/N     6500.0        CUA          Cuauhtémoc       NaN           1
# 288    S/N     6500.0          1  Ampliación Granada       NaN           8
# 172    S/N     6500.0        CUA          Cuauhtémoc       NaN           5
# 364    S/N     6500.0        CUA          Cuauhtémoc       NaN           2
#
#      location/l  ...  nearbySt_3 nearbySt_4  nearbySt_5  \
# 295   19.433571  ...         NaN        NaN         NaN
# 173   19.431386  ...         NaN        NaN         NaN
# 288   19.431655  ...         NaN        NaN         NaN
# 172   19.428309  ...        10.0        NaN         NaN
# 364   19.429720  ...        10.0        NaN         NaN
#
#                   punto_geo  CVE_AGEB  CVE_MUN  CVE_LOC CVE_ENT  MOVEMENT_I  \
# 295  19.4335714,-99.1678091       790       15        1       9        4749
# 173    19.431386,-99.171695       926       15        1       9        4661
# 288    19.431655,-99.158668       729       15        1       9        4746
# 172    19.428309,-99.171713       926       15        1       9        4661
# 364     19.42972,-99.169363       822       15        1       9        4800
#
#              DISPLAY_NA
# 295  Movement Zone 4749
# 173  Movement Zone 4661
# 288  Movement Zone 4746
# 172  Movement Zone 4661
# 364  Movement Zone 4800
#
# [5 rows x 24 columns]

# %% [markdown]
# ## Prueba

# %% [raw]
# set(df_estaciones["ID"]) - set(df_viajes["Ciclo_Estacion_Arribo"])

# %% [markdown]
# ## Viajes ecobici

# %%
df_viajes = pd.read_csv('./data/ecobici/ecobici_2019.csv',sep=',')
df_viajes.head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,1,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1   9196                   136                     55            36
# 2   2612                   115                     29            38
# 3   7463                   115                     29            43
# 4   3987                    35                    136            37
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro Unnamed: 9
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44        NaN
# 1   01/01/2019   01/01/2019              M     0:42:11     0:12:05        NaN
# 2   01/01/2019   01/01/2019              M     0:37:47     0:13:15        NaN
# 3   01/01/2019   01/01/2019              M     0:38:04     0:13:36        NaN
# 4   01/01/2019   01/01/2019              M     0:22:47     0:15:30        NaN

# %% [markdown]
# ### merge viajes e info de estaciones
#
# Se obtiene ageb por estación de origen y destino.

# %% [markdown]
# #### Clave AGEB arribo

# %%
df_viajes_ageb = df_viajes.merge(df_estaciones[['ID','CVE_AGEB',"Nombre"]], left_on='Ciclo_Estacion_Retiro', right_on='ID')

# %%
df_viajes_ageb.rename(columns={'CVE_AGEB': 'CVE_AGEB_retiro'}, inplace=True)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11835                    67                     67            46
# 2  11906                   447                     67            28
# 3   8651                   447                     67            26
# 4   8647                    66                     67            59
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro Unnamed: 9  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44        NaN
# 1   01/01/2019   01/01/2019              M     0:33:19     0:27:40        NaN
# 2   01/01/2019   01/01/2019              M    13:46:17    13:39:44        NaN
# 3   01/01/2019   01/01/2019              M    13:46:20    13:40:01        NaN
# 4   01/01/2019   01/01/2019              M    14:14:53    13:45:09        NaN
#
#    ID  CVE_AGEB_retiro                       Nombre
# 0  67             1318  67 VICENTE SUAREZ-MICHOACAN
# 1  67             1318  67 VICENTE SUAREZ-MICHOACAN
# 2  67             1318  67 VICENTE SUAREZ-MICHOACAN
# 3  67             1318  67 VICENTE SUAREZ-MICHOACAN
# 4  67             1318  67 VICENTE SUAREZ-MICHOACAN

# %% [markdown]
# #### Clave AGEB destino

# %%
df_viajes_ageb = df_viajes_ageb.merge(df_estaciones[['ID','CVE_AGEB',"Nombre"]], left_on='Ciclo_Estacion_Arribo', right_on='ID')

# %%
df_viajes_ageb.rename(columns={'CVE_AGEB': 'CVE_AGEB_arribo'}, inplace=True)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro Unnamed: 9  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44        NaN
# 1   01/01/2019   01/01/2019              M    23:02:34    22:57:15        NaN
# 2   02/01/2019   02/01/2019              M     7:42:30     7:38:25        NaN
# 3   03/01/2019   03/01/2019              M     7:41:55     7:37:37        NaN
# 4   03/01/2019   03/01/2019              M     8:37:24     8:32:25        NaN
#
#    ID_x  CVE_AGEB_retiro                     Nombre_x  ID_y  CVE_AGEB_arribo  \
# 0    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
# 1    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
# 2    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
# 3    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
# 4    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
#
#              Nombre_y
# 0  36 PUEBLA-VERACRUZ
# 1  36 PUEBLA-VERACRUZ
# 2  36 PUEBLA-VERACRUZ
# 3  36 PUEBLA-VERACRUZ
# 4  36 PUEBLA-VERACRUZ

# %% [markdown]
# ## Renombramos las columnas de nombre:

# %%
df_viajes_ageb.rename({"Nombre_x":"nombre_estacion_retiro","Nombre_y":"nombre_estacion_arribo"},axis=1,inplace=True)
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro Unnamed: 9  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44        NaN
# 1   01/01/2019   01/01/2019              M    23:02:34    22:57:15        NaN
# 2   02/01/2019   02/01/2019              M     7:42:30     7:38:25        NaN
# 3   03/01/2019   03/01/2019              M     7:41:55     7:37:37        NaN
# 4   03/01/2019   03/01/2019              M     8:37:24     8:32:25        NaN
#
#    ID_x  CVE_AGEB_retiro       nombre_estacion_retiro  ID_y  CVE_AGEB_arribo  \
# 0    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
# 1    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
# 2    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
# 3    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
# 4    67             1318  67 VICENTE SUAREZ-MICHOACAN    36             1089
#
#   nombre_estacion_arribo
# 0     36 PUEBLA-VERACRUZ
# 1     36 PUEBLA-VERACRUZ
# 2     36 PUEBLA-VERACRUZ
# 3     36 PUEBLA-VERACRUZ
# 4     36 PUEBLA-VERACRUZ

# %% [markdown]
# ### Eliminamos columnas no usadas

# %%
df_viajes_ageb.columns
# Out:
# Index(['Bici', 'Ciclo_Estacion_Arribo', 'Ciclo_Estacion_Retiro',
#        'Edad_Usuario', 'Fecha_Arribo', 'Fecha_Retiro', 'Genero_Usuario',
#        'Hora_Arribo', 'Hora_Retiro', 'Unnamed: 9', 'ID_x', 'CVE_AGEB_retiro',
#        'nombre_estacion_retiro', 'ID_y', 'CVE_AGEB_arribo',
#        'nombre_estacion_arribo'],
#       dtype='object')

# %%
df_viajes_ageb.drop(['Unnamed: 9','ID_x','ID_y'], axis=1, inplace=True)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44
# 1   01/01/2019   01/01/2019              M    23:02:34    22:57:15
# 2   02/01/2019   02/01/2019              M     7:42:30     7:38:25
# 3   03/01/2019   03/01/2019              M     7:41:55     7:37:37
# 4   03/01/2019   03/01/2019              M     8:37:24     8:32:25
#
#    CVE_AGEB_retiro       nombre_estacion_retiro  CVE_AGEB_arribo  \
# 0             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 1             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 2             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 3             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 4             1318  67 VICENTE SUAREZ-MICHOACAN             1089
#
#   nombre_estacion_arribo
# 0     36 PUEBLA-VERACRUZ
# 1     36 PUEBLA-VERACRUZ
# 2     36 PUEBLA-VERACRUZ
# 3     36 PUEBLA-VERACRUZ
# 4     36 PUEBLA-VERACRUZ

# %% [markdown]
# ## Obtenemos la columna de hora de retiro:

# %%
df_viajes_ageb['Hora_Retiro_round'] = df_viajes_ageb['Hora_Retiro'].str.split(':').str[0].astype(int)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro  \
# 0   01/01/2019   01/01/2019              M     0:14:03     0:08:44
# 1   01/01/2019   01/01/2019              M    23:02:34    22:57:15
# 2   02/01/2019   02/01/2019              M     7:42:30     7:38:25
# 3   03/01/2019   03/01/2019              M     7:41:55     7:37:37
# 4   03/01/2019   03/01/2019              M     8:37:24     8:32:25
#
#    CVE_AGEB_retiro       nombre_estacion_retiro  CVE_AGEB_arribo  \
# 0             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 1             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 2             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 3             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 4             1318  67 VICENTE SUAREZ-MICHOACAN             1089
#
#   nombre_estacion_arribo  Hora_Retiro_round
# 0     36 PUEBLA-VERACRUZ                  0
# 1     36 PUEBLA-VERACRUZ                 22
# 2     36 PUEBLA-VERACRUZ                  7
# 3     36 PUEBLA-VERACRUZ                  7
# 4     36 PUEBLA-VERACRUZ                  8

# %% [markdown]
# ## Obtenemos el tiempo de cada viaje:

# %% [markdown]
# Eliminamos filas con errores de formato:

# %%
df_viajes_ageb[df_viajes_ageb['Hora_Retiro']=='18::']
# Out:
#          Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 5746668  8026                   400                     18            19
#
#         Fecha_Arribo Fecha_Retiro Genero_Usuario Hora_Arribo Hora_Retiro  \
# 5746668   28/04/2019   26/04/2019              M    01:15:10        18::
#
#          CVE_AGEB_retiro             Nombre_x  CVE_AGEB_arribo  \
# 5746668              837  18 REFORMA-RIO RHIN              755
#
#                                 Nombre_y  Hora_Retiro_round
# 5746668  400 SAN LORENZO-HERIBERTO FRIAS                 18

# %%
index_number = df_viajes_ageb[df_viajes_ageb['Hora_Retiro']=='18::'].index.values[0]
df_viajes_ageb.drop([index_number],inplace=True)

# %% [markdown]
# Convetimos a datetime:

# %%
df_viajes_ageb['Hora_Retiro'] = pd.to_datetime(df_viajes_ageb['Hora_Retiro'], format='%H:%M:%S')

df_viajes_ageb['Hora_Arribo'] = pd.to_datetime(df_viajes_ageb['Hora_Arribo'], format='%H:%M:%S')

# %% [markdown]
# Verificamos que las horas de arribo y reutro sean datetime

# %% [markdown]
# restamos las columnas para obtener el tiempo

# %%
df_viajes_ageb['duracion_viaje'] = df_viajes_ageb['Hora_Arribo'] - df_viajes_ageb['Hora_Retiro']

# %%
df_viajes_ageb['duracion_viaje_minutos'] = df_viajes_ageb['duracion_viaje'].astype('str').str.split(':').str[1].astype(int)

# %%
df_viajes_ageb.head()
# Out:
#     Bici Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario  \
# 0  11444                    36                     67            36
# 1  11194                    36                     67            36
# 2  10750                    36                     67            34
# 3   6963                    36                     67            34
# 4   9663                    36                     67            24
#
#   Fecha_Arribo Fecha_Retiro Genero_Usuario         Hora_Arribo  \
# 0   01/01/2019   01/01/2019              M 1900-01-01 00:14:03
# 1   01/01/2019   01/01/2019              M 1900-01-01 23:02:34
# 2   02/01/2019   02/01/2019              M 1900-01-01 07:42:30
# 3   03/01/2019   03/01/2019              M 1900-01-01 07:41:55
# 4   03/01/2019   03/01/2019              M 1900-01-01 08:37:24
#
#           Hora_Retiro  CVE_AGEB_retiro       nombre_estacion_retiro  \
# 0 1900-01-01 00:08:44             1318  67 VICENTE SUAREZ-MICHOACAN
# 1 1900-01-01 22:57:15             1318  67 VICENTE SUAREZ-MICHOACAN
# 2 1900-01-01 07:38:25             1318  67 VICENTE SUAREZ-MICHOACAN
# 3 1900-01-01 07:37:37             1318  67 VICENTE SUAREZ-MICHOACAN
# 4 1900-01-01 08:32:25             1318  67 VICENTE SUAREZ-MICHOACAN
#
#    CVE_AGEB_arribo nombre_estacion_arribo  Hora_Retiro_round duracion_viaje  \
# 0             1089     36 PUEBLA-VERACRUZ                  0       00:05:19
# 1             1089     36 PUEBLA-VERACRUZ                 22       00:05:19
# 2             1089     36 PUEBLA-VERACRUZ                  7       00:04:05
# 3             1089     36 PUEBLA-VERACRUZ                  7       00:04:18
# 4             1089     36 PUEBLA-VERACRUZ                  8       00:04:59
#
#    duracion_viaje_minutos
# 0                       5
# 1                       5
# 2                       4
# 3                       4
# 4                       4

# %%
df_viajes_ageb.drop(['Bici','Fecha_Arribo',
                    'Fecha_Retiro','duracion_viaje','Hora_Arribo','Hora_Retiro'], axis=1, inplace=True)

# %%
df_viajes_ageb.head()
# Out:
#   Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario Genero_Usuario  \
# 0                    36                     67            36              M
# 1                    36                     67            36              M
# 2                    36                     67            34              M
# 3                    36                     67            34              M
# 4                    36                     67            24              M
#
#    CVE_AGEB_retiro       nombre_estacion_retiro  CVE_AGEB_arribo  \
# 0             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 1             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 2             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 3             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 4             1318  67 VICENTE SUAREZ-MICHOACAN             1089
#
#   nombre_estacion_arribo  Hora_Retiro_round  duracion_viaje_minutos
# 0     36 PUEBLA-VERACRUZ                  0                       5
# 1     36 PUEBLA-VERACRUZ                 22                       5
# 2     36 PUEBLA-VERACRUZ                  7                       4
# 3     36 PUEBLA-VERACRUZ                  7                       4
# 4     36 PUEBLA-VERACRUZ                  8                       4

# %% [markdown]
# ### Estos datos se usaran para obtener los viajes de una estación a otra por ageb.

# %%
df_viajes_ageb.to_csv('./data/procesado/datos_ecobici_por_ageb.csv',index=False)

# %%
df_viajes_ageb.head()
# Out:
#   Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario Genero_Usuario  \
# 0                    36                     67            36              M
# 1                    36                     67            36              M
# 2                    36                     67            34              M
# 3                    36                     67            34              M
# 4                    36                     67            24              M
#
#    CVE_AGEB_retiro       nombre_estacion_retiro  CVE_AGEB_arribo  \
# 0             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 1             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 2             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 3             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 4             1318  67 VICENTE SUAREZ-MICHOACAN             1089
#
#   nombre_estacion_arribo  Hora_Retiro_round  duracion_viaje_minutos
# 0     36 PUEBLA-VERACRUZ                  0                       5
# 1     36 PUEBLA-VERACRUZ                 22                       5
# 2     36 PUEBLA-VERACRUZ                  7                       4
# 3     36 PUEBLA-VERACRUZ                  7                       4
# 4     36 PUEBLA-VERACRUZ                  8                       4

# %% [markdown]
# ### Obtención de genero de usuarios por viaje:

# %%
df_viajes_ageb['Genero_Usuario_F'] = pd.get_dummies(df_viajes_ageb['Genero_Usuario'])["F"]
df_viajes_ageb['Genero_Usuario_M'] = pd.get_dummies(df_viajes_ageb['Genero_Usuario'])["M"]

# %%
print(df_viajes_ageb['CVE_AGEB_retiro'].nunique(),df_viajes_ageb['CVE_AGEB_arribo'].nunique())
# Out:
# 142 142

# %%
df_viajes_ageb.head()
# Out:
#   Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario Genero_Usuario  \
# 0                    36                     67            36              M
# 1                    36                     67            36              M
# 2                    36                     67            34              M
# 3                    36                     67            34              M
# 4                    36                     67            24              M
#
#    CVE_AGEB_retiro                     Nombre_x  CVE_AGEB_arribo  \
# 0             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 1             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 2             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 3             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 4             1318  67 VICENTE SUAREZ-MICHOACAN             1089
#
#              Nombre_y  Hora_Retiro_round  duracion_viaje_minutos  \
# 0  36 PUEBLA-VERACRUZ                  0                       5
# 1  36 PUEBLA-VERACRUZ                 22                       5
# 2  36 PUEBLA-VERACRUZ                  7                       4
# 3  36 PUEBLA-VERACRUZ                  7                       4
# 4  36 PUEBLA-VERACRUZ                  8                       4
#
#    Genero_Usuario_F  Genero_Usuario_M
# 0                 0                 1
# 1                 0                 1
# 2                 0                 1
# 3                 0                 1
# 4                 0                 1

# %%
print(df_viajes_ageb['CVE_AGEB_retiro'].nunique(),df_viajes_ageb['CVE_AGEB_arribo'].nunique())
# Out:
# 142 142

# %%
df_viajes_ageb_agg = df_viajes_ageb.groupby(['CVE_AGEB_arribo','CVE_AGEB_retiro','Hora_Retiro_round' ]).agg({'Edad_Usuario':['count', 'mean'], 
                         'duracion_viaje_minutos':['mean','min','max'],
                                                                                       'Genero_Usuario_F':['sum'],
                                                                                       'Genero_Usuario_M':['sum'],
                                                                                      
                                                                                      }).reset_index(drop=False)
df_viajes_ageb_agg.columns = ['_'.join(col) for col in df_viajes_ageb_agg.columns]

# %%
df_viajes_ageb_agg.head(5)
# Out:
#    CVE_AGEB_arribo_  CVE_AGEB_retiro_  Hora_Retiro_round_  Edad_Usuario_count  \
# 0                 5                 5                   0                   7
# 1                 5                 5                   2                   1
# 2                 5                 5                   5                   2
# 3                 5                 5                   6                 110
# 4                 5                 5                   7                 147
#
#    Edad_Usuario_mean  duracion_viaje_minutos_mean  duracion_viaje_minutos_min  \
# 0          35.857143                    15.857143                           9
# 1          40.000000                     5.000000                           5
# 2          30.000000                     3.000000                           3
# 3          46.490909                     2.518182                           1
# 4          33.462585                     3.795918                           1
#
#    duracion_viaje_minutos_max  Genero_Usuario_F_sum  Genero_Usuario_M_sum
# 0                          27                   0.0                   7.0
# 1                           5                   0.0                   1.0
# 2                           3                   0.0                   2.0
# 3                          11                  93.0                  17.0
# 4                          34                  16.0                 131.0

# %% [markdown]
# Definimos una función para obtener el número de mujeres y de hombres:

# %%
def procentaje_homvres(row):
    return round(row['Genero_Usuario_M_sum']*10 / (row['Genero_Usuario_F_sum'] + row['Genero_Usuario_M_sum']),0)

# %%
df_viajes_ageb_agg['porcentage_hombres'] = df_viajes_ageb_agg.apply(procentaje_homvres, axis=1)

# %%
df_viajes_ageb_agg['porcentage_mujeres'] = 10 - df_viajes_ageb_agg['porcentage_hombres']

# %%
df_viajes_ageb_agg.head()
# Out:
#    CVE_AGEB_arribo_  CVE_AGEB_retiro_  Hora_Retiro_round_  Edad_Usuario_count  \
# 0                 5                 5                   0                   7
# 1                 5                 5                   2                   1
# 2                 5                 5                   5                   2
# 3                 5                 5                   6                 110
# 4                 5                 5                   7                 147
#
#    Edad_Usuario_mean  duracion_viaje_minutos_mean  duracion_viaje_minutos_min  \
# 0          35.857143                    15.857143                           9
# 1          40.000000                     5.000000                           5
# 2          30.000000                     3.000000                           3
# 3          46.490909                     2.518182                           1
# 4          33.462585                     3.795918                           1
#
#    duracion_viaje_minutos_max  Genero_Usuario_F_sum  Genero_Usuario_M_sum  \
# 0                          27                   0.0                   7.0
# 1                           5                   0.0                   1.0
# 2                           3                   0.0                   2.0
# 3                          11                  93.0                  17.0
# 4                          34                  16.0                 131.0
#
#    porcentage_hombres  porcentage_mujeres
# 0                10.0                 0.0
# 1                10.0                 0.0
# 2                10.0                 0.0
# 3                 2.0                 8.0
# 4                 9.0                 1.0

# %%
df_viajes_ageb_agg.to_csv('./data/production_data/viajes_ecobici.csv',index=False)
