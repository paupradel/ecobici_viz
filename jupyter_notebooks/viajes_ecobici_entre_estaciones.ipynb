# %% [markdown]
# ### Viajes Ecobici entre estaciones de ecobici

# %% [markdown]
# __Descripción:__
#
# Se obtiene las estaciones dentro de un ageb y se muestra el número de viajes a otro ageb
#
# __Input__
#
# - Estaciones de ecobici: Estaciones de ecobici con clave AGEB obtenida de __Uber © 2019 Copyright Uber Technologies, Inc.Data Attributions__
#
# - Viajes Ecobici 2019
# Responsable: Ecobici

# %%
import pandas as pd

# %% [markdown]
# ## Estaciones

# %%
df_viajes = pd.read_csv('./data/procesado/datos_ecobici_por_ageb.csv',sep=',')
df_viajes.head()
# Out:
#    Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  Edad_Usuario Genero_Usuario  \
# 0                     36                     67            36              M
# 1                     36                     67            36              M
# 2                     36                     67            34              M
# 3                     36                     67            34              M
# 4                     36                     67            24              M
#
#    CVE_AGEB_retiro       nombre_estacion_retiro  CVE_AGEB_arribo  \
# 0             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 1             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 2             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 3             1318  67 VICENTE SUAREZ-MICHOACAN             1089
# 4             1318  67 VICENTE SUAREZ-MICHOACAN             1089
#
#   nombre_estacion_arribo  Hora_Retiro_round  duracion_viaje_minutos
# 0     36 PUEBLA-VERACRUZ                  0                       5
# 1     36 PUEBLA-VERACRUZ                 22                       5
# 2     36 PUEBLA-VERACRUZ                  7                       4
# 3     36 PUEBLA-VERACRUZ                  7                       4
# 4     36 PUEBLA-VERACRUZ                  8                       4

# %%
df_viajes_gb = df_viajes.groupby([
    'Ciclo_Estacion_Arribo','Ciclo_Estacion_Retiro',"CVE_AGEB_retiro","CVE_AGEB_arribo","nombre_estacion_retiro","nombre_estacion_arribo"
                                ])[["Edad_Usuario"]].count().reset_index(drop=False)

# %%
df_viajes_gb.head()
# Out:
#    Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  CVE_AGEB_retiro  \
# 0                      1                      1              790
# 1                      1                      2              926
# 2                      1                      3              729
# 3                      1                      4              926
# 4                      1                      5              822
#
#    CVE_AGEB_arribo         nombre_estacion_retiro nombre_estacion_arribo  \
# 0              790          1 RIO SENA-RIO BALSAS  1 RIO SENA-RIO BALSAS
# 1              790  2 RIO GUADALQUIVIR-RIO BALSAS  1 RIO SENA-RIO BALSAS
# 2              790          3 REFORMA-INSURGENTES  1 RIO SENA-RIO BALSAS
# 3              790          4 RIO NILO-RIO PANUCO  1 RIO SENA-RIO BALSAS
# 4              790         5 RIO PANUCO-RIO TIBER  1 RIO SENA-RIO BALSAS
#
#    Edad_Usuario
# 0          1609
# 1           610
# 2           280
# 3           696
# 4           803

# %% [markdown]
# ## Quitamos el numero de la columna estación:

# %%
df_viajes_gb["nombre_estacion_retiro"] = df_viajes_gb["nombre_estacion_retiro"].str.strip("1234567890")
df_viajes_gb["nombre_estacion_arribo"] = df_viajes_gb["nombre_estacion_arribo"].str.strip("1234567890")

# %%
df_viajes_gb.head()
# Out:
#    Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  CVE_AGEB_retiro  \
# 0                      1                      1              790
# 1                      1                      2              926
# 2                      1                      3              729
# 3                      1                      4              926
# 4                      1                      5              822
#
#    CVE_AGEB_arribo        nombre_estacion_retiro nombre_estacion_arribo  \
# 0              790           RIO SENA-RIO BALSAS    RIO SENA-RIO BALSAS
# 1              790   RIO GUADALQUIVIR-RIO BALSAS    RIO SENA-RIO BALSAS
# 2              790           REFORMA-INSURGENTES    RIO SENA-RIO BALSAS
# 3              790           RIO NILO-RIO PANUCO    RIO SENA-RIO BALSAS
# 4              790          RIO PANUCO-RIO TIBER    RIO SENA-RIO BALSAS
#
#    Edad_Usuario
# 0          1609
# 1           610
# 2           280
# 3           696
# 4           803

# %% [markdown]
# ## renombramos:

# %%
df_viajes_gb.rename({"Edad_Usuario":"Numero_de_viajes"},axis=1,inplace=True)

# %%
df_viajes_gb.head()
# Out:
#    Ciclo_Estacion_Arribo  Ciclo_Estacion_Retiro  CVE_AGEB_retiro  \
# 0                      1                      1              790
# 1                      1                      2              926
# 2                      1                      3              729
# 3                      1                      4              926
# 4                      1                      5              822
#
#    CVE_AGEB_arribo        nombre_estacion_retiro nombre_estacion_arribo  \
# 0              790           RIO SENA-RIO BALSAS    RIO SENA-RIO BALSAS
# 1              790   RIO GUADALQUIVIR-RIO BALSAS    RIO SENA-RIO BALSAS
# 2              790           REFORMA-INSURGENTES    RIO SENA-RIO BALSAS
# 3              790           RIO NILO-RIO PANUCO    RIO SENA-RIO BALSAS
# 4              790          RIO PANUCO-RIO TIBER    RIO SENA-RIO BALSAS
#
#    Numero_de_viajes
# 0              1609
# 1               610
# 2               280
# 3               696
# 4               803

# %% [markdown]
# ## Guardamos

# %%
df_viajes_gb.to_csv("./data/production_data/viajes_ecobici_entre_estaciones.csv",index=False)
